# %%
import os
import sys

sys.path.append("/mnt/workdata/_WORK_/mail_zonning/mail_zoning/classes")

import datetime as dt
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = "true"

import numpy as np
from numpy.lib.stride_tricks import sliding_window_view
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import mlflow
import json
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import itertools
from tqdm import tqdm
import inspect
import matplotlib.pyplot as plt
import seaborn as sns
from sentence_classifier import MovingWindowSentenceClassifier

for m in [pd, tf, tfa, mlflow]:
    print(f"{m.__name__:20s}\t{m.__version__}")

tf.config.experimental.enable_tensor_float_32_execution(enabled=True)

DATAPATH = "/mnt/workdata/_WORK_/mail_zonning/mail_zoning/dataset/enron_files_annotated/"
# Out:
# pandas              	1.5.0
# tensorflow          	2.9.2
# tensorflow_addons   	0.18.0
# mlflow              	1.29.0

# %% [markdown]
# # Supporting methods

# %%
def prepare_dataset(datapath: str):
    def extract_text(text, flags: dict):
        text = text.split('\n')
        idx = 0
        while text[idx][:2] not in flags:
            idx += 1
        labels = [flags[t[:2]] for t in text[idx:] if len(t) > 1]
        text = [t[2:] for t in text[idx:]]
        return text, labels

    # load and extract flag data
    FLAGS = {'B>': 0, 'H>': 1, 'S>': 2}
    files = {}
    for filename in os.listdir(datapath):
        with open(os.path.join(datapath, filename), 'rt') as f:
            files[filename] = f.read()
    _ = []
    for filename in files.keys():
        text_ = files[filename]
        textlines, labels = extract_text(text_, FLAGS)
        for idx, line_label in enumerate(zip(textlines, labels)):
            _.append({'doc': filename, 'idx': idx, 'sentence': line_label[0], 'label': line_label[1]})
    df = pd.DataFrame.from_dict(_)
    return df

def split_dataset(data: pd.DataFrame, random_state: int):
    """"
    Dataset split is based on complete emails, not on email lines
    """
    splitter = KFold(n_splits=5, shuffle=True, random_state=random_state)
    docs = data['doc'].unique()
    splits = splitter.split(docs)
    train_data = []
    val_data = []
    for train_idx, val_idx in splits:
        train_data_ = data.loc[data['doc'].isin(docs[train_idx])]
        train_data.append(train_data_[['doc', 'idx', 'sentence', 'label']])
        val_data_ = data.loc[data['doc'].isin(docs[val_idx])]
        val_data.append(val_data_[['doc', 'idx', 'sentence', 'label']])
    return train_data, val_data

# %% [markdown]
# ## Window size = 3

# %%
model_params = {
    "output_class_count": 3,
    "vocab_size": 8000,
    "output_sequence_length": 45,
    "embedding_dimension": 150,
    "window_size": 3,
    "conv1d_0_units": 80,
    "conv1d_0_kernelsize": 3,
    "conv1d_0_padding": "valid",
    "conv1d_0_activation": "relu",
    "conv1d_1_units": 80,
    "conv1d_1_kernelsize": 3,
    "conv1d_1_padding": "valid",
    "conv1d_1_activation": "relu",
    "gru_0_units": 128,
    "gru_1_units": 64,
    "drop_0_rate": 0.3448836829019953,
    "initial_lr": 0.0006500000000000001,
    "lr_reduction_factor": 0.44531593652922397,
    "lr_reduction_patience": 3,
    "batch_size": 56,
    "max_epochs": 100,
    "early_stop_patience": 10
}
RANDOM_STATE=123
df = prepare_dataset(DATAPATH)
train_subsets, val_subsets = split_dataset(df, RANDOM_STATE)

texts = df['sentence'].values
results={}
for idx in range(len(train_subsets)):
    tf.keras.backend.clear_session()
    clf=MovingWindowSentenceClassifier(
        model_params=model_params,
        bod_line = 'This is the first line of document. No lines come before.',
        eod_line='This is the last line of document. No lines come after.',
        corpus=texts)
    clf.prepare_train_records(data=train_subsets[idx])
    clf.prepare_validation_records(data=val_subsets[idx])
    clf.compile(optimizer=tf.keras.optimizers.Adam(model_params['initial_lr']),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
    clf.fit(
            x=clf.train_texts, y=clf.train_labels,
            batch_size=model_params['batch_size'],
            epochs=model_params['max_epochs'],
            validation_data=(clf.validation_texts, clf.validation_labels),
            use_multiprocessing=True,
            callbacks=[
                tf.keras.callbacks.ReduceLROnPlateau(
                    factor=model_params['lr_reduction_factor'], patience=model_params['lr_reduction_patience'], verbose=0),
                tf.keras.callbacks.EarlyStopping(
                    min_delta=1e-4, patience=model_params['early_stop_patience'], restore_best_weights=True)
            ],verbose=1)
    results[idx]=clf.evaluate(clf.validation_texts, clf.validation_labels)

master_results={3:results}
# Out:
# 2022-12-04 11:16:58.509805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.516957: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.517193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.517932: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-04 11:16:58.520429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.520629: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.520804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.807492: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.807664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.807796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 11:16:58.807878: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-12-04 11:16:58.807900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22292 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:21:00.0, compute capability: 8.6
# Epoch 1/100
# 2022-12-04 11:17:03.928721: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2022-12-04 11:17:04.354674: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-12-04 11:17:04.987385: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 196/196 [==============================] - 7s 12ms/step - loss: 0.2686 - accuracy: 0.9014 - val_loss: 0.4452 - val_accuracy: 0.8962 - lr: 6.5000e-04
# Epoch 2/100
# 196/196 [==============================] - 1s 8ms/step - loss: 0.0590 - accuracy: 0.9821 - val_loss: 0.1302 - val_accuracy: 0.9684 - lr: 6.5000e-04
# Epoch 3/100
# 196/196 [==============================] - 1s 8ms/step - loss: 0.0404 - accuracy: 0.9878 - val_loss: 0.0680 - val_accuracy: 0.9846 - lr: 6.5000e-04
# Epoch 4/100
# 196/196 [==============================] - 1s 8ms/step - loss: 0.0334 - accuracy: 0.9898 - val_loss: 0.0583 - val_accuracy: 0.9842 - lr: 6.5000e-04
# Epoch 5/100
# 196/196 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9912 - val_loss: 0.0551 - val_accuracy: 0.9853 - lr: 6.5000e-04
# Epoch 6/100
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0294 - accuracy: 0.9913 - val_loss: 0.0616 - val_accuracy: 0.9860 - lr: 6.5000e-04
# Epoch 7/100
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0274 - accuracy: 0.9918 - val_loss: 0.0585 - val_accuracy: 0.9856 - lr: 6.5000e-04
# Epoch 8/100
# 196/196 [==============================] - 1s 8ms/step - loss: 0.0290 - accuracy: 0.9916 - val_loss: 0.0499 - val_accuracy: 0.9881 - lr: 6.5000e-04
# Epoch 9/100
# 196/196 [==============================] - 1s 7ms/step - loss: 0.
# Epoch 7/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0293 - accuracy: 0.9919 - val_loss: 0.1503 - val_accuracy: 0.9668 - lr: 6.5000e-04
# Epoch 8/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0266 - accuracy: 0.9920 - val_loss: 0.1378 - val_accuracy: 0.9676 - lr: 2.8946e-04
# Epoch 9/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0255 - accuracy: 0.9928 - val_loss: 0.1287 - val_accuracy: 0.9737 - lr: 2.8946e-04
# Epoch 10/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0251 - accuracy: 0.9928 - val_loss: 0.1362 - val_accuracy: 0.9721 - lr: 2.8946e-04
# Epoch 11/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0247 - accuracy: 0.9929 - val_loss: 0.1381 - val_accuracy: 0.9709 - lr: 1.2890e-04
# Epoch 12/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0244 - accuracy: 0.9930 - val_loss: 0.1371 - val_accuracy: 0.9721 - lr: 1.2890e-04
# Epoch 13/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0243 - accuracy: 0.9929 - val_loss: 0.1390 - val_accuracy: 0.9721 - lr: 1.2890e-04
# Epoch 14/100
# 202/202 [==============================] - 1s 7ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.1406 - val_accuracy: 0.9721 - lr: 5.7401e-05
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 0.9750

# %% [markdown]
# ## Window size = 5

# %%
model_params = {
    "output_class_count": 3,
    "vocab_size": 8000,
    "output_sequence_length": 45,
    "embedding_dimension": 150,
    "window_size": 5,
    "conv1d_0_units": 80,
    "conv1d_0_kernelsize": 3,
    "conv1d_0_padding": "valid",
    "conv1d_0_activation": "relu",
    "conv1d_1_units": 80,
    "conv1d_1_kernelsize": 3,
    "conv1d_1_padding": "valid",
    "conv1d_1_activation": "relu",
    "gru_0_units": 128,
    "gru_1_units": 64,
    "drop_0_rate": 0.3448836829019953,
    "initial_lr": 0.0006500000000000001,
    "lr_reduction_factor": 0.44531593652922397,
    "lr_reduction_patience": 3,
    "batch_size": 56,
    "max_epochs": 100,
    "early_stop_patience": 10
}
RANDOM_STATE=123
df = prepare_dataset(DATAPATH)
train_subsets, val_subsets = split_dataset(df, RANDOM_STATE)

texts = df['sentence'].values
results={}
for idx in range(len(train_subsets)):
    tf.keras.backend.clear_session()
    clf=MovingWindowSentenceClassifier(
        model_params=model_params,
        bod_line = 'This is the first line of document. No lines come before.',
        eod_line='This is the last line of document. No lines come after.',
        corpus=texts)
    clf.prepare_train_records(data=train_subsets[idx])
    clf.prepare_validation_records(data=val_subsets[idx])
    clf.compile(optimizer=tf.keras.optimizers.Adam(model_params['initial_lr']),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
    clf.fit(
            x=clf.train_texts, y=clf.train_labels,
            batch_size=model_params['batch_size'],
            epochs=model_params['max_epochs'],
            validation_data=(clf.validation_texts, clf.validation_labels),
            use_multiprocessing=True,
            callbacks=[
                tf.keras.callbacks.ReduceLROnPlateau(
                    factor=model_params['lr_reduction_factor'], patience=model_params['lr_reduction_patience'], verbose=0),
                tf.keras.callbacks.EarlyStopping(
                    min_delta=1e-4, patience=model_params['early_stop_patience'], restore_best_weights=True)
            ],verbose=1)
    results[idx]=clf.evaluate(clf.validation_texts, clf.validation_labels)

master_results[5]=results
# Out:
# Epoch 1/100
# 196/196 [==============================] - 6s 12ms/step - loss: 0.2354 - accuracy: 0.9130 - val_loss: 0.4242 - val_accuracy: 0.8193 - lr: 6.5000e-04
# Epoch 2/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0407 - accuracy: 0.9858 - val_loss: 0.0793 - val_accuracy: 0.9802 - lr: 6.5000e-04
# Epoch 3/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0231 - accuracy: 0.9933 - val_loss: 0.0319 - val_accuracy: 0.9925 - lr: 6.5000e-04
# Epoch 4/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0363 - val_accuracy: 0.9917 - lr: 6.5000e-04
# Epoch 5/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.0375 - val_accuracy: 0.9874 - lr: 6.5000e-04
# Epoch 6/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0300 - val_accuracy: 0.9921 - lr: 6.5000e-04
# Epoch 7/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0251 - val_accuracy: 0.9943 - lr: 6.5000e-04
# Epoch 8/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.1670 - val_accuracy: 0.9353 - lr: 6.5000e-04
# Epoch 9/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0229 - val_accuracy: 0.9935 - lr: 6.5000e-04
# Epoch 10/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0226 - val_accuracy: 0.9903 - lr: 6.5000e-04
# Epoch 11/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0232 - val_accuracy: 0.9928 - lr: 6.5000e-04
# Epoch 12/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0249 - val_accuracy: 0.9921 - lr: 6.5000e-04
# Epoch 13/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0272 - val_accuracy: 0.9928 - lr: 6.5000e-04
# Epoch 14/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0232 - val_accuracy: 0.9928 - lr: 2.8946e-04
# Epoch 15/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0247 - val_accuracy: 0.9921 - lr: 2.8946e-04
# Epoch 16/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0246 - val_accuracy: 0.9928 - lr: 2.8946e-04
# Epoch 17/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0249 - val_accuracy: 0.9928 - lr: 1.2890e-04
# Epoch 18/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0264 - val_accuracy: 0.9914 - lr: 1.2890e-04
# Epoch 19/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0276 - val_accuracy: 0.9907 - lr: 1.2890e-04
# Epoch 20/100
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0270 - val_accuracy: 0.9907 - lr: 5.7401e-05
# 87/87 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9903
# Epoch 1/100
# 198/198 [==============================] - 6s 12ms/step - loss: 0.2194 - accuracy: 0.9166 - val_loss: 0.4036 - val_accuracy: 0.8038 - lr: 6.5000e-04
# Epoch 2/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0415 - accuracy: 0.9855 - val_loss: 0.1102 - val_accuracy: 0.9716 - lr: 6.5000e-04
# Epoch 3/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 0.0343 - val_accuracy: 0.9925 - lr: 6.5000e-04
# Epoch 4/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.0341 - val_accuracy: 0.9869 - lr: 6.5000e-04
# Epoch 5/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0471 - val_accuracy: 0.9854 - lr: 6.5000e-04
# Epoch 6/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0284 - val_accuracy: 0.9914 - lr: 6.5000e-04
# Epoch 7/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.0278 - val_accuracy: 0.9929 - lr: 6.5000e-04
# Epoch 8/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.1238 - val_accuracy: 0.9746 - lr: 6.5000e-04
# Epoch 9/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.1812 - val_accuracy: 0.9735 - lr: 6.5000e-04
# Epoch 10/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0436 - val_accuracy: 0.9869 - lr: 6.5000e-04
# Epoch 11/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0418 - val_accuracy: 0.9880 - lr: 2.8946e-04
# Epoch 12/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0341 - val_accuracy: 0.9895 - lr: 2.8946e-04
# Epoch 13/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0532 - val_accuracy: 0.9858 - lr: 2.8946e-04
# Epoch 14/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0469 - val_accuracy: 0.9865 - lr: 1.2890e-04
# Epoch 15/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0467 - val_accuracy: 0.9865 - lr: 1.2890e-04
# Epoch 16/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0451 - val_accuracy: 0.9880 - lr: 1.2890e-04
# Epoch 17/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0480 - val_accuracy: 0.9858 - lr: 5.7401e-05
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9929
# Epoch 1/100
# 195/195 [==============================] - 6s 12ms/step - loss: 0.2320 - accuracy: 0.9153 - val_loss: 0.4158 - val_accuracy: 0.8512 - lr: 6.5000e-04
# Epoch 2/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0381 - accuracy: 0.9861 - val_loss: 0.1428 - val_accuracy: 0.9706 - lr: 6.5000e-04
# Epoch 3/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0237 - accuracy: 0.9930 - val_loss: 0.1475 - val_accuracy: 0.9518 - lr: 6.5000e-04
# Epoch 4/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0968 - val_accuracy: 0.9801 - lr: 6.5000e-04
# Epoch 5/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.1257 - val_accuracy: 0.9794 - lr: 6.5000e-04
# Epoch 6/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.1513 - val_accuracy: 0.9633 - lr: 6.5000e-04
# Epoch 7/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.1994 - val_accuracy: 0.9507 - lr: 6.5000e-04
# Epoch 8/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.1344 - val_accuracy: 0.9724 - lr: 2.8946e-04
# Epoch 9/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.1286 - val_accuracy: 0.9766 - lr: 2.8946e-04
# Epoch 10/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.1533 - val_accuracy: 0.9738 - lr: 2.8946e-04
# Epoch 11/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.1495 - val_accuracy: 0.9752 - lr: 1.2890e-04
# Epoch 12/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1799 - val_accuracy: 0.9640 - lr: 1.2890e-04
# Epoch 13/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1561 - val_accuracy: 0.9745 - lr: 1.2890e-04
# Epoch 14/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1598 - val_accuracy: 0.9731 - lr: 5.7401e-05
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0968 - accuracy: 0.9801
# Epoch 1/100
# 193/193 [==============================] - 6s 12ms/step - loss: 0.2309 - accuracy: 0.9129 - val_loss: 0.5523 - val_accuracy: 0.6786 - lr: 6.5000e-04
# Epoch 2/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0410 - accuracy: 0.9862 - val_loss: 0.1872 - val_accuracy: 0.9428 - lr: 6.5000e-04
# Epoch 3/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0230 - accuracy: 0.9937 - val_loss: 0.0840 - val_accuracy: 0.9719 - lr: 6.5000e-04
# Epoch 4/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0661 - val_accuracy: 0.9823 - lr: 6.5000e-04
# Epoch 5/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 0.0590 - val_accuracy: 0.9866 - lr: 6.5000e-04
# Epoch 6/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0493 - val_accuracy: 0.9876 - lr: 6.5000e-04
# Epoch 7/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0746 - val_accuracy: 0.9839 - lr: 6.5000e-04
# Epoch 8/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0706 - val_accuracy: 0.9853 - lr: 6.5000e-04
# Epoch 9/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.0601 - val_accuracy: 0.9880 - lr: 6.5000e-04
# Epoch 10/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0683 - val_accuracy: 0.9873 - lr: 2.8946e-04
# Epoch 11/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0738 - val_accuracy: 0.9873 - lr: 2.8946e-04
# Epoch 12/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0547 - val_accuracy: 0.9880 - lr: 2.8946e-04
# Epoch 13/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0669 - val_accuracy: 0.9880 - lr: 1.2890e-04
# Epoch 14/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0648 - val_accuracy: 0.9880 - lr: 1.2890e-04
# Epoch 15/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0676 - val_accuracy: 0.9880 - lr: 1.2890e-04
# Epoch 16/100
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0710 - val_accuracy: 0.9880 - lr: 5.7401e-05
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0493 - accuracy: 0.9876
# Epoch 1/100
# 202/202 [==============================] - 5s 11ms/step - loss: 0.2091 - accuracy: 0.9251 - val_loss: 0.3681 - val_accuracy: 0.8167 - lr: 6.5000e-04
# Epoch 2/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0433 - accuracy: 0.9858 - val_loss: 0.1019 - val_accuracy: 0.9791 - lr: 6.5000e-04
# Epoch 3/100
# 202/202 [==============================] - 2s 7ms/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0987 - val_accuracy: 0.9742 - lr: 6.5000e-04
# Epoch 4/100
# 202/202 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.1152 - val_accuracy: 0.9783 - lr: 6.5000e-04
# Epoch 5/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.1178 - val_accuracy: 0.9766 - lr: 6.5000e-04
# Epoch 6/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.1083 - val_accuracy: 0.9856 - lr: 6.5000e-04
# Epoch 7/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.1382 - val_accuracy: 0.9766 - lr: 2.8946e-04
# Epoch 8/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.1585 - val_accuracy: 0.9733 - lr: 2.8946e-04
# Epoch 9/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.1477 - val_accuracy: 0.9750 - lr: 2.8946e-04
# Epoch 10/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.1340 - val_accuracy: 0.9766 - lr: 1.2890e-04
# Epoch 11/100
# 202/202 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.1449 - val_accuracy: 0.9774 - lr: 1.2890e-04
# Epoch 12/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.1331 - val_accuracy: 0.9766 - lr: 1.2890e-04
# Epoch 13/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.1348 - val_accuracy: 0.9766 - lr: 5.7401e-05
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0987 - accuracy: 0.9742

# %% [markdown]
# ## Window size = 7

# %%
model_params = {
    "output_class_count": 3,
    "vocab_size": 8000,
    "output_sequence_length": 45,
    "embedding_dimension": 150,
    "window_size": 7,
    "conv1d_0_units": 80,
    "conv1d_0_kernelsize": 3,
    "conv1d_0_padding": "valid",
    "conv1d_0_activation": "relu",
    "conv1d_1_units": 80,
    "conv1d_1_kernelsize": 3,
    "conv1d_1_padding": "valid",
    "conv1d_1_activation": "relu",
    "gru_0_units": 128,
    "gru_1_units": 64,
    "drop_0_rate": 0.3448836829019953,
    "initial_lr": 0.0006500000000000001,
    "lr_reduction_factor": 0.44531593652922397,
    "lr_reduction_patience": 3,
    "batch_size": 56,
    "max_epochs": 100,
    "early_stop_patience": 10
}
RANDOM_STATE=123
df = prepare_dataset(DATAPATH)
train_subsets, val_subsets = split_dataset(df, RANDOM_STATE)

texts = df['sentence'].values
results={}
for idx in range(len(train_subsets)):
    tf.keras.backend.clear_session()
    clf=MovingWindowSentenceClassifier(
        model_params=model_params,
        bod_line = 'This is the first line of document. No lines come before.',
        eod_line='This is the last line of document. No lines come after.',
        corpus=texts)
    clf.prepare_train_records(data=train_subsets[idx])
    clf.prepare_validation_records(data=val_subsets[idx])
    clf.compile(optimizer=tf.keras.optimizers.Adam(model_params['initial_lr']),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
    clf.fit(
            x=clf.train_texts, y=clf.train_labels,
            batch_size=model_params['batch_size'],
            epochs=model_params['max_epochs'],
            validation_data=(clf.validation_texts, clf.validation_labels),
            use_multiprocessing=True,
            callbacks=[
                tf.keras.callbacks.ReduceLROnPlateau(
                    factor=model_params['lr_reduction_factor'], patience=model_params['lr_reduction_patience'], verbose=0),
                tf.keras.callbacks.EarlyStopping(
                    min_delta=1e-4, patience=model_params['early_stop_patience'], restore_best_weights=True)
            ],verbose=1)
    results[idx]=clf.evaluate(clf.validation_texts, clf.validation_labels)

master_results[7]=results
# Out:
# Epoch 1/100
# 196/196 [==============================] - 6s 13ms/step - loss: 0.2105 - accuracy: 0.9226 - val_loss: 0.3417 - val_accuracy: 0.8797 - lr: 6.5000e-04
# Epoch 2/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0404 - accuracy: 0.9858 - val_loss: 0.0964 - val_accuracy: 0.9831 - lr: 6.5000e-04
# Epoch 3/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 0.0274 - val_accuracy: 0.9921 - lr: 6.5000e-04
# Epoch 4/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0162 - val_accuracy: 0.9943 - lr: 6.5000e-04
# Epoch 5/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0363 - val_accuracy: 0.9878 - lr: 6.5000e-04
# Epoch 6/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0291 - val_accuracy: 0.9910 - lr: 6.5000e-04
# Epoch 7/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0320 - val_accuracy: 0.9910 - lr: 6.5000e-04
# Epoch 8/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0286 - val_accuracy: 0.9903 - lr: 2.8946e-04
# Epoch 9/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0307 - val_accuracy: 0.9903 - lr: 2.8946e-04
# Epoch 10/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0239 - val_accuracy: 0.9939 - lr: 2.8946e-04
# Epoch 11/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0459 - val_accuracy: 0.9846 - lr: 1.2890e-04
# Epoch 12/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0427 - val_accuracy: 0.9853 - lr: 1.2890e-04
# Epoch 13/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0309 - val_accuracy: 0.9896 - lr: 1.2890e-04
# Epoch 14/100
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0279 - val_accuracy: 0.9917 - lr: 5.7401e-05
# 87/87 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9943
# Epoch 1/100
# 198/198 [==============================] - 6s 15ms/step - loss: 0.1977 - accuracy: 0.9253 - val_loss: 0.3791 - val_accuracy: 0.8087 - lr: 6.5000e-04
# Epoch 2/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0360 - accuracy: 0.9876 - val_loss: 0.0894 - val_accuracy: 0.9824 - lr: 6.5000e-04
# Epoch 3/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0208 - accuracy: 0.9933 - val_loss: 0.0613 - val_accuracy: 0.9809 - lr: 6.5000e-04
# Epoch 4/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0444 - val_accuracy: 0.9865 - lr: 6.5000e-04
# Epoch 5/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0634 - val_accuracy: 0.9854 - lr: 6.5000e-04
# Epoch 6/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.1084 - val_accuracy: 0.9817 - lr: 6.5000e-04
# Epoch 7/100
# 198/198 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0593 - val_accuracy: 0.9877 - lr: 6.5000e-04
# Epoch 8/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0628 - val_accuracy: 0.9869 - lr: 2.8946e-04
# Epoch 9/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0712 - val_accuracy: 0.9862 - lr: 2.8946e-04
# Epoch 10/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0766 - val_accuracy: 0.9862 - lr: 2.8946e-04
# Epoch 11/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0832 - val_accuracy: 0.9862 - lr: 1.2890e-04
# Epoch 12/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0740 - val_accuracy: 0.9862 - lr: 1.2890e-04
# Epoch 13/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0704 - val_accuracy: 0.9869 - lr: 1.2890e-04
# Epoch 14/100
# 198/198 [==============================] - 2s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0778 - val_accuracy: 0.9862 - lr: 5.7401e-05
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0444 - accuracy: 0.9865
# Epoch 1/100
# 195/195 [==============================] - 5s 12ms/step - loss: 0.2157 - accuracy: 0.9172 - val_loss: 0.3047 - val_accuracy: 0.8711 - lr: 6.5000e-04
# Epoch 2/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0342 - accuracy: 0.9887 - val_loss: 0.1708 - val_accuracy: 0.9437 - lr: 6.5000e-04
# Epoch 3/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.1756 - val_accuracy: 0.9553 - lr: 6.5000e-04
# Epoch 4/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 0.3070 - val_accuracy: 0.9396 - lr: 6.5000e-04
# Epoch 5/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.3394 - val_accuracy: 0.9340 - lr: 6.5000e-04
# Epoch 6/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.2909 - val_accuracy: 0.9514 - lr: 2.8946e-04
# Epoch 7/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.3260 - val_accuracy: 0.9518 - lr: 2.8946e-04
# Epoch 8/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.3645 - val_accuracy: 0.9483 - lr: 2.8946e-04
# Epoch 9/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.3817 - val_accuracy: 0.9441 - lr: 1.2890e-04
# Epoch 10/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.3619 - val_accuracy: 0.9518 - lr: 1.2890e-04
# Epoch 11/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.4045 - val_accuracy: 0.9434 - lr: 1.2890e-04
# Epoch 12/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.3807 - val_accuracy: 0.9476 - lr: 5.7401e-05
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1708 - accuracy: 0.9437
# Epoch 1/100
# 193/193 [==============================] - 6s 13ms/step - loss: 0.2124 - accuracy: 0.9218 - val_loss: 0.5174 - val_accuracy: 0.8371 - lr: 6.5000e-04
# Epoch 2/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0384 - accuracy: 0.9870 - val_loss: 0.1203 - val_accuracy: 0.9552 - lr: 6.5000e-04
# Epoch 3/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0174 - accuracy: 0.9951 - val_loss: 0.0522 - val_accuracy: 0.9819 - lr: 6.5000e-04
# Epoch 4/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0262 - val_accuracy: 0.9916 - lr: 6.5000e-04
# Epoch 5/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0301 - val_accuracy: 0.9900 - lr: 6.5000e-04
# Epoch 6/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.0442 - val_accuracy: 0.9866 - lr: 6.5000e-04
# Epoch 7/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0709 - val_accuracy: 0.9793 - lr: 6.5000e-04
# Epoch 8/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0206 - val_accuracy: 0.9940 - lr: 2.8946e-04
# Epoch 9/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0137 - val_accuracy: 0.9943 - lr: 2.8946e-04
# Epoch 10/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0185 - val_accuracy: 0.9933 - lr: 2.8946e-04
# Epoch 11/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0160 - val_accuracy: 0.9960 - lr: 2.8946e-04
# Epoch 12/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0153 - val_accuracy: 0.9957 - lr: 2.8946e-04
# Epoch 13/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0184 - val_accuracy: 0.9950 - lr: 1.2890e-04
# Epoch 14/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0192 - val_accuracy: 0.9936 - lr: 1.2890e-04
# Epoch 15/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0188 - val_accuracy: 0.9936 - lr: 1.2890e-04
# Epoch 16/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0163 - val_accuracy: 0.9950 - lr: 5.7401e-05
# Epoch 17/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0179 - val_accuracy: 0.9943 - lr: 5.7401e-05
# Epoch 18/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0202 - val_accuracy: 0.9936 - lr: 5.7401e-05
# Epoch 19/100
# 193/193 [==============================] - 2s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0192 - val_accuracy: 0.9943 - lr: 2.5561e-05
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9943
# Epoch 1/100
# 202/202 [==============================] - 5s 12ms/step - loss: 0.2036 - accuracy: 0.9206 - val_loss: 0.3498 - val_accuracy: 0.8893 - lr: 6.5000e-04
# Epoch 2/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0357 - accuracy: 0.9877 - val_loss: 0.1215 - val_accuracy: 0.9578 - lr: 6.5000e-04
# Epoch 3/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.1224 - val_accuracy: 0.9594 - lr: 6.5000e-04
# Epoch 4/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.1353 - val_accuracy: 0.9684 - lr: 6.5000e-04
# Epoch 5/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.1445 - val_accuracy: 0.9664 - lr: 6.5000e-04
# Epoch 6/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.1598 - val_accuracy: 0.9680 - lr: 2.8946e-04
# Epoch 7/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.1347 - val_accuracy: 0.9709 - lr: 2.8946e-04
# Epoch 8/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.1368 - val_accuracy: 0.9709 - lr: 2.8946e-04
# Epoch 9/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1577 - val_accuracy: 0.9692 - lr: 1.2890e-04
# Epoch 10/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1672 - val_accuracy: 0.9692 - lr: 1.2890e-04
# Epoch 11/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1697 - val_accuracy: 0.9701 - lr: 1.2890e-04
# Epoch 12/100
# 202/202 [==============================] - 2s 8ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1625 - val_accuracy: 0.9709 - lr: 5.7401e-05
# 77/77 [==============================] - 0s 3ms/step - loss: 0.1215 - accuracy: 0.9578

# %% [markdown]
# # Results comparison

# %%
_={(k,s): {'val_loss':master_results[k][s][0], 'val_accuracy': master_results[k][s][1]}
 for k in master_results.keys() for s in master_results[k].keys()}
_ = pd.DataFrame.from_dict(_).T.reset_index()
_.columns=['window size','split num', 'val loss', 'val accuracy']

fig, ax=plt.subplots(1,2,figsize=(14,6))
sns.barplot(data=_, x= 'split num', y='val loss', hue='window size',palette='rainbow', ax=ax[0])
ax[0].set_title("Validation loss values for window sizes")
sns.barplot(data=_, x= 'split num', y='val accuracy', hue='window size',palette='rainbow', ax=ax[1])
ax[0].set_title("Validation accuracy values for window sizes")
ax[1].set_ylim(0.9, 1.0)
# Out:
# (0.9, 1.0)
